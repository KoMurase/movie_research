# %%
path = "./csv"

# %%
import pandas as pd

# %%
import os

# %%
os.listdir(path)
# Out:
# ['SF.csv', 'アドベンチャー・冒険.csv', 'コメディ.csv', '青春.csv']

# %%
data = pd.read_csv(path+"/SF.csv")
pd.set_option('display.max_rows', 500)

# %%
import numpy as np
len(data[data["あらすじ"].isnull()==True])
# Out:
# 317

# %%
data
# Out:
#        レビュー数 平均スコア                       タイトル(日本名)  \
# 0    147430件  4.0点                         インセプション
# 1    136332件  4.2点                        インターステラー
# 2    150490件  4.2点                 バック・トゥ・ザ・フューチャー
# 3      1453件  3.2点                   レベル16 服従の少女たち
# 4     85829件  3.9点                      トゥルーマン・ショー
# 5     79199件  3.4点                             ミスト
# 6     72844件  3.8点                      時計じかけのオレンジ
# 7    100132件  4.0点               マッドマックス 怒りのデス・ロード
# 8    103547件  4.0点                      レディ・プレイヤー1
# 9     83146件  3.8点                            E.T.
# 10    74129件  3.8点                          マトリックス
# 11    82018件  4.1点            バック・トゥ・ザ・フューチャーPART3
# 12    14449件  3.8点                         アップグレード
# 13   124017件  3.8点                           オデッセイ
# 14    91806件  4.0点                             NaN
# 15   100039件  3.9点                         アベンジャーズ
# 16    97884件  3.7点                      メン・イン・ブラック
# ...

# %%
len(data)
# Out:
# 468

# %%
len(data[data["平均スコア"]=="-点"])
# Out:
# 37

# %%
data[data["平均スコア"]=="-点"]
# Out:
#     レビュー数 平均スコア タイトル(日本名)                              タイトル(英名)    製作日  \
# 36     0件    -点       NaN                         Chaos Walking  2021年
# 66     0件    -点       NaN                                  Live  2020年
# 69    10件    -点       NaN                          The Matrix 4  2021年
# 114    0件    -点       NaN                              Infinite  2020年
# 118    0件    -点       NaN                            After Yang  2020年
# 129    0件    -点       NaN                      Army of the Dead    NaN
# 230    0件    -点       NaN                    Return of the Ewok  1982年
# 262    0件    -点       NaN     INTERGALACTIC／Dark Side of Heaven  2008年
# 271    1件    -点       NaN                          Lazer Team 2  2018年
# 273    0件    -点       NaN                          Solar Impact  2019年
# 275    0件    -点       NaN                           Earthkiller  2011年
# 277    0件    -点       NaN                        Blood Machines  2019年
# ...

# %%
data[data["タイトル(日本名)"].isnull()]
# Out:
#       レビュー数 平均スコア タイトル(日本名)  \
# 14   91806件  4.0点       NaN
# 27    4234件  3.5点       NaN
# 29    2245件  3.8点       NaN
# 31      21件  3.5点       NaN
# 36       0件    -点       NaN
# 38     202件  3.4点       NaN
# 46     404件  2.9点       NaN
# 47       4件  4.5点       NaN
# 48     201件  3.8点       NaN
# 51     329件  2.7点       NaN
# 53      17件  4.2点       NaN
# 57     130件  2.6点       NaN
# 58      98件  3.3点       NaN
# 62      11件  3.7点       NaN
# 64       2件  4.3点       NaN
# 65       6件  2.4点       NaN
# 66       0件    -点       NaN
# 67      61件  3.1点       NaN
# 69      10件    -点       NaN
# 73    1886件  3.1点       NaN
# 74    1227件  3.1点       NaN
# 86     151件  3.8点       NaN
# 88     434件  3.3点       NaN
# 89      26件  3.2点       NaN
# 93      88件  3.4点       NaN
# 94     153件  3.6点       NaN
# 96     183件  3.2点       NaN
# 101    323件  2.6点       NaN
# 102    233件  1.4点       NaN
# 103    174件  2.9点       NaN
# ..      ...   ...       ...
# 312      0件    -点       NaN
# ...

# %%
data["タイトル(日本名)"].values[14]
# Out:
# nan

# %%
def title(df):
    df = df.copy()
    Nan = np.nan
    data[data["タイトル(日本名)"] == Nan]:
        title = data["タイトル(日本名)"]
    else:
        title = data["タイトル(英名)"]
        
    df['title'] = title
        
    return title

# %%
NaN = np.nan
data[data["タイトル(日本名)"].isnull()==True]
# Out:
#       レビュー数 平均スコア タイトル(日本名)  \
# 14   91806件  4.0点       NaN
# 27    4234件  3.5点       NaN
# 29    2245件  3.8点       NaN
# 31      21件  3.5点       NaN
# 36       0件    -点       NaN
# 38     202件  3.4点       NaN
# 46     404件  2.9点       NaN
# 47       4件  4.5点       NaN
# 48     201件  3.8点       NaN
# 51     329件  2.7点       NaN
# 53      17件  4.2点       NaN
# 57     130件  2.6点       NaN
# 58      98件  3.3点       NaN
# 62      11件  3.7点       NaN
# 64       2件  4.3点       NaN
# 65       6件  2.4点       NaN
# 66       0件    -点       NaN
# 67      61件  3.1点       NaN
# 69      10件    -点       NaN
# 73    1886件  3.1点       NaN
# 74    1227件  3.1点       NaN
# 86     151件  3.8点       NaN
# 88     434件  3.3点       NaN
# 89      26件  3.2点       NaN
# 93      88件  3.4点       NaN
# 94     153件  3.6点       NaN
# 96     183件  3.2点       NaN
# 101    323件  2.6点       NaN
# 102    233件  1.4点       NaN
# 103    174件  2.9点       NaN
# ..      ...   ...       ...
# 312      0件    -点       NaN
# ...

# %%
data[data["タイトル(英名)"].isnull()==True]
# Out:
#       レビュー数 平均スコア                     タイトル(日本名) タイトル(英名)    製作日  \
# 22    6904件  3.3点                 GODZILLA 怪獣惑星      NaN  2017年
# 27    4234件  3.5点                           NaN      NaN  2000年
# 37    1707件  3.3点    コードギアス 亡国のアキト／第2章 引き裂かれし翼竜      NaN  2013年
# 51     329件  2.7点                           NaN      NaN  1989年
# 56      97件  2.3点                     A.I.ライジング      NaN  2018年
# 75    1373件  2.8点                悪夢ちゃん The夢ovie      NaN  2014年
# 84     324件  3.2点                          紅い眼鏡      NaN  1987年
# 88     434件  3.3点                           NaN      NaN  2003年
# 93      88件  3.4点                           NaN      NaN  2016年
# 98     259件  3.1点  MEATBALL MACHINE -ミートボールマシン-      NaN  2005年
# 99     334件  2.8点                     死びとの恋わずらい      NaN  2000年
# 108    182件  2.6点                       時をかける少女      NaN  1997年
# 110    188件  2.5点                           NaN      NaN  1983年
# 112    187件  3.2点                           NaN      NaN  1992年
# ...
