# %%
path = "./csv"

# %%
import pandas as pd

# %%
data = pd.read_csv(path+"/アドベンチャー・冒険.csv")
data
# Out:
#        レビュー数 平均スコア                 タイトル(日本名)  \
# 0    146712件  4.0点                   インセプション
# 1    135994件  4.2点                  インターステラー
# 2     31010件  4.0点                       NaN
# 3    127912件  4.0点                スタンド・バイ・ミー
# 4    135826件  4.1点                      アラジン
# 5    150229件  4.2点           バック・トゥ・ザ・フューチャー
# 6    164542件  3.9点             ハリー・ポッターと賢者の石
# 7    133838件  3.8点            ハリー・ポッターと秘密の部屋
# 8     99943件  4.0点         マッドマックス 怒りのデス・ロード
# 9    127755件  3.9点         ハリー・ポッターとアズカバンの囚人
# 10    79122件  3.8点      ものすごくうるさくて、ありえないほど近い
# 11     3415件  3.9点          ザ・ピーナッツバター・ファルコン
# 12   116892件  3.8点          ハリー・ポッターと炎のゴブレット
# 13      323件    -点                       NaN
# 14    39123件  3.4点             デイ・アフター・トゥモロー
# 15    81809件  4.1点      バック・トゥ・ザ・フューチャーPART3
# 16   114603件  3.8点          ハリー・ポッターと不死鳥の騎士団
# 17   103368件  4.0点                レディ・プレイヤー1
# 18   104786件  3.8点       ハリー・ポッターと死の秘宝 PART1
# 19    96209件  3.8点                     LIFE!
# ...
