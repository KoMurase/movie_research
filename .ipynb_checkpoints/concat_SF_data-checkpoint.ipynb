# %%
import pandas as pd
import os

# %%
path = "./review_csv/SF"
folders = os.listdir(path)
folders
# Out:
# ['12モンキーズ',
#  '2001年宇宙の旅',
#  '2001年宇宙の旅 新世紀特別版',
#  '200X年翔',
#  '2010年',
#  '2012',
#  '2020世界終焉の日',
#  '20世紀少年＜最終章＞ぼくらの旗',
#  '20世紀少年＜第1章＞終わりの始まり',
#  '20世紀少年＜第2章＞ 最後の希望',
#  '41',
#  'A1012K',
#  'AI',
#  'AIライジング',
#  'ANIARAアニアーラ',
#  'Archive原題',
#  'Ares英題',
#  'Astro原題',
#  'Auggie原題',
#  'AXLアクセル',
#  'Bacurau原題',
#  'Beyond the Sky原題',
#  'BillTedFacetheMusic原題',
#  'BLAMEブラム',
#  'Clara原題',
#  'Code8原題',
#  'ColdGround原題',
#  'COSMICRESCUETheMoonlightGenerations',
#  'CrazyAlien英題',
#  'CreatorsThePast原題',
#  'CreepyCrawlers英題',
#  'CrittersAttack原題',
#  'Dune 原題',
#  'ET',
#  'ET20周年アニバーサリー特別版',
#  'Fast Color原題',
#  'FREAKSフリークス能力者たち',
#  'GODZILLA ゴジラ',
#  'GODZILLA 怪獣惑星',
#  'I predatori di Atlantide／Atlantis Interceptors原題',
#  'Imitation Girl原題',
#  'Incontrol原題',
#  'iPSイントリュージョンオブプレデターステムセル',
#  'JurassicWorldDominion原題',
#  'LUCY／ルーシー',
#  'MEATBALLMACHINEミートボールマシン',
#  'MonsterHunt2英題',
#  'ParadiseHills原題',
#  'PLANETOFTHEAPES猿の惑星',
#  'PORTALSポータルズ',
#  'PREDATORPLANETプレデタープラネット',
#  'PRIVATEDREAMS',
#  'Pro9治験',
#  'PROSPECTプロスペクト',
#  'Psycho Goreman原題',
#  'Seat25原題',
#  'SFヘルスラッシャー',
#  'SFホイップクリーム',
#  'SinFin原題',
#  'Starfish原題',
#  'SUPER8／スーパーエイト',
#  'TakingTigerMountain原題',
#  'TAU／タウ',
#  'The Beast of Yucca Flats原題',
#  'TheCaseoftheMorituriDivisions英題',
#  'TheComingDays英題',
#  'TheDoll原題',
#  'TheInvisibleMansRevenge原題',
#  'TheInvisibleWoman原題',
#  'TheMonsterofPiedrasBlancas原題',
#  'TheNewMutants原題',
#  'ThePlatform英題',
#  'TheWave原題',
#  'TIME／タイム',
#  'TreasureoftheBitchIslands英題',
#  'UFOAbduction原題',
#  'UFO少年アブドラジャン',
#  'UnderElectricClouds英題',
#  'Vivarium原題',
#  'XMENファーストジェネレーション',
#  'Zero原題',
#  'だいじょうぶマイフレンド',
#  'てなもんや商社',
#  'アイアムレジェンド',
#  'アイススパイダー',
#  'アイランド',
#  'アイロボット',
#  'アキュムレーター1',
#  'アジアの逆襲',
#  'アジャストメント',
#  'アップグレード',
#  'アナイアレイション全滅領域',
#  'アフターアース',
#  'アベンジャーズ',
#  'アリーナ',
#  'アルファヴィル',
#  'アルマゲドン',
#  'アローン',
#  'アンドリューNDR114',
#  'アンドロメダストレイン',
#  'イカリエXB1',
#  'インセプション',
#  'インターステラー',
#  'インターセプター',
#  'インデペンデンスデイ',
#  'インデペンデンスデイ2019',
#  'インビジブル',
#  'インフィニティ無限ループ',
#  'イヴァーンヴァシーリエヴィチ転職する',
#  'ウォーターワールド',
#  'エイプマンの復讐',
#  'エイリアン',
#  'エイリアン2',
#  'エイリアン3',
#  'エイリアンVS プレデター',
#  'エイリアンアタック',
#  'エイリアントルネード',
#  'エイリアンノイド',
#  'エイリアンバトルロワイヤル',
#  'エイリアンフロムメテオ侵略',
#  'エイリアン／ディレクターズカット',
#  'エクスチェンジ脳間電送',
#  'エクスティンクション地球奪還',
#  'エリエリレマサバクタニ',
#  'エリジウム',
#  'エンドオブアース',
#  'エヴォリューション',
#  'オキュペーション侵略',
#  'オデッセイ',
#  'オブリビオン',
#  'オールユーニードイズキル',
#  'ガイバー／ダークヒーロー',
#  'ガジュラ',
#  'ガタカ',
#  'ガーディアンズオブギャラクシー：リミックス',
#  'キルボット',
#  'ギャラクシークエスト',
#  'クマエロヒーム',
#  'クリムゾンプラネット',
#  'クリーチャーオブダークネス',
#  'クロニクル',
#  'クローバーフィールドパラドックス',
#  'グリーンランタン',
#  'グレンとグレンダ',
#  'コクーン',
#  'コクーン2 遥かなる地球',
#  'コクーン2遥かなる地球',
#  'コロニー５',
#  'コンタクト',
#  'コードギアス亡国のアキト／第2章引き裂かれし翼竜',
#  'ゴーストインザシェル',
#  'サイキッカー 超人覚醒',
#  'サイボーグハンター ニューヨーク2019年',
#  'サイン',
#  'サインオブゴッド',
#  'サークルズ',
#  'ザコア',
#  'ザコンタクト',
#  'ザトランスフォーム',
#  'ザフライ',
#  'ザプロジェクト瞬間移動',
#  'ザホスト美しき侵略者',
#  'ザミスト',
#  'シャットダウン',
#  'ショートサーキット',
#  'ジェシカ',
#  'ジャンパー',
#  'ジュテームジュテーム',
#  'ジュピター',
#  'ジュブナイル',
#  'ジュラシックエクスペディション',
#  'ジュラシックサバイブ',
#  'ジュラシックワールド炎の王国',
#  'ジョナサンふたつの顔の男',
#  'スターウォーズ エピソード1／ファントムメナス',
#  'スターウォーズ エピソード2／クローンの攻撃',
#  'スターウォーズ エピソード3／シスの復讐',
#  'スターウォーズ エピソード4／新たなる希望',
#  'スターウォーズ エピソード5／帝国の逆襲',
#  'スターウォーズエピソード1／ファントムメナス',
#  'スターウォーズエピソード3／シスの復讐',
#  'スターウォーズエピソード4／新たなる希望',
#  'スターウォーズエピソード5／帝国の逆襲',
#  'スターウォーズエピソード6／ジェダイの帰還',
#  'スターウォーズ／ジェダイの帰還 特別篇',
#  'スターウォーズ／フォースの覚醒',
#  'スターウォーズ／帝国の逆襲特別篇',
#  'スターウォーズ／最後のジェダイ',
#  'スターシップトゥルーパーズ',
#  'スタートレック',
#  'スタートレックイントゥダークネス',
#  'ストーカー',
#  'スノーピアサー',
#  'スパイダーズ',
#  'スピーシーズXX寄生獣の誘惑',
#  'スペースエクスペンダブルズ',
#  'スペースポリス',
#  'スペースヴァンパイアQ',
#  'スローンズ 王都奪還',
#  'スーパーカミング完全版',
#  'スーパーマンリターンズ',
#  'セリーナ最強の暗殺者',
#  'ゼイカム到来',
#  'ゼログラビティ',
#  'ソリス',
#  'ソードレジェンド失われたドラゴンの剣',
#  'タイタン',
#  'タイタンAE',
#  'タイムトラベラー',
#  'ターミネーター',
#  'ターミネーター ニューフェイト',
#  'ターミネーター2',
#  'ターミネーター3',
#  'ターミネーター4',
#  'ターミネーターウォー',
#  'ターミネーター：新起動／ジェニシス',
#  'ダイバージェント',
#  'チキチキバンバン',
#  'チャッピー',
#  'ディストピア2049',
#  'デコーダー',
#  'デジャヴ',
#  'デスゲーム2025',
#  'デッドシティ2055',
#  'デメキング DEMEKING',
#  'デメキングDEMEKING',
#  'トゥルーマンショー',
#  'トランスフォーマー',
#  'トランスフォーマー最後の騎士王',
#  'トランスフォーマー／ダークサイドムーン',
#  'トランスフォーマー／リベンジ',
#  'トランスフォーマー／ロストエイジ',
#  'トランスモーファー人類最終戦争',
#  'トランセンデンス',
#  'トロン：レガシー',
#  'トワイライトゾーン／超次元の体験',
#  'トータルリコール',
#  'ドウエル教授の首',
#  'ドッペルゲンガー複製された者',
#  'ニューヨーク2014',
#  'ニルヴァーナ',
#  'ネイビーシールズ vs エイリアン',
#  'ネバーエンディングストーリー3',
#  'ネメシス',
#  'ノイズ',
#  'ノウイング',
#  'ハイライフ',
#  'ハイルミュタンテ／電撃XX作戦',
#  'ハルマゲドン',
#  'ハンガーゲーム',
#  'ハンガーゲーム FINAL：レボリューション',
#  'ハンガーゲーム2',
#  'ハンガーゲームFINAL：レジスタンス',
#  'ハンガーフォード',
#  'バタフライエフェクト',
#  'バックトゥザフューチャー',
#  'バックトゥザフューチャーPART2',
#  'バックトゥザフューチャーPART3',
#  'バトルシップ',
#  'バトルスカイ',
#  'バトルドローン',
#  'バトルハザード',
#  'バベル失われた地図と魔法の水晶',
#  'パシフィックリム',
#  'パシフィックリムアップライジング',
#  'パラサイト地球外生命体',
#  'ヒズマスターズヴォイス',
#  'ピクセル',
#  'ピノキオニューアドベンチャー',
#  'ファイナルハザード',
#  'ファイナルフェーズ 破壊',
#  'ファーストコンタクト',
#  'フィフスエレメント',
#  'フィフスパッセンジャー',
#  'フランケンウィニー',
#  'フレッシュゴードン／SPACEWARS',
#  'ブライトバーン恐怖の拡散者',
#  'ブラックパンサー',
#  'ブラックミラーバンダースナッチ',
#  'ブレードランナー',
#  'ブレードランナー2049',
#  'ブレードランナーファイナルカット',
#  'ブロンクスウォリアーズ／1990年の戦士',
#  'プラネットオブエイリアン',
#  'プラン9フロムアウタースペース',
#  'プレデターズ',
#  'プロトタイプマナ制御不能',
#  'プロメテウス',
#  'ホテルアルテミス～犯罪者専門闇病院～',
#  'ホワイトスペース',
#  'ホンモノの気持ち',
#  'ボルケーノアルマゲドン',
#  'ポストアポカリプス',
#  'ポーラーサークル未知なる漫画家オムニバス',
#  'マシーンオブザデッド',
#  'マダムハイド',
#  'マックィーンの絶対の危機ピンチ',
#  'マッドファイター',
#  'マッドマックス2',
#  'マッドマックス怒りのデスロード',
#  'マッドレイジ Z',
#  'マトリックス',
#  'マトリックス レボリューションズ',
#  'マトリックスリローデッド',
#  'マペットのクリスマスキャロル',
#  'マンオブスティール',
#  'マーズアタック',
#  'ミクロキッズ3',
#  'ミスト',
#  'ミッション8ミニッツ',
#  'ミムジー 〜未来からのメッセージ〜',
#  'ミラクルニール',
#  'メッセージ',
#  'メトロポリス',
#  'メトロポリス 完全復元版',
#  'メンインブラック',
#  'メンインブラック2',
#  'メンインブラック3',
#  'メンインブラック：インターナショナル',
#  'モンスターアイランド',
#  'ライフ',
#  'ラジュテ',
#  'ラストフランケンシュタイン',
#  'ラストマン地球最後の男',
#  'ラストラブレター',
#  'ラビッド',
#  'ランドオブザロスト',
#  'リアリティ',
#  'リディック：ギャラクシーバトル',
#  'リバーワールド',
#  'リミットレス',
#  'ルーシーインザスカイ',
#  'レイトフォーディナー',
#  'レッドサイクロン',
#  'レディプレイヤー1',
#  'レプリカズ',
#  'レプリケイト－襲撃－',
#  'レベル16服従の少女たち',
#  'ロストチルドレン',
#  'ロックアップスペースロック',
#  'ロックダウン非常事態',
#  'ロックネス',
#  'ロボコップ',
#  'ロボジョックス',
#  'ロボットコップレボリューション',
#  'ワールズエンド酔っぱらいが世界を救う',
#  'ワールドエンド',
#  'ヴァストオブナイト',
#  'ヴァレリアン千の惑星の救世主',
#  'ヴィクターフランケンシュタイン',
#  '三人の夫',
#  '世界侵略 ワシントン決戦',
#  '世界侵略ロサンゼルス決戦',
#  '世紀の怪物／タランチュラの襲撃',
#  '丹波哲郎の大霊界2 死んだらおどろいた',
#  '丹波哲郎の大霊界2死んだらおどろいた',
#  '丹波哲郎の大霊界死んだらどうなる',
#  '人類滅亡計画書',
#  '今日昨日明日',
#  '吸血鬼ゴケミドロ',
#  '囚われた国家',
#  '地球が静止する日',
#  '地球を守れ',
#  '大災獣ニゲロン',
#  '天才少年ジミーニュートロン',
#  '孤独なふりした世界で',
#  '宇宙人ポール',
#  '宇宙少女ゼノン',
#  '宇宙戦争',
#  '宇宙水爆戦',
#  '宮田バスターズ株',
#  '寄生体X',
#  '寄生獣',
#  '巨大目玉の怪獣トロレンバーグの恐怖',
#  '幻の湖',
#  '怪物の花嫁',
#  '恋はデジャブ',
#  '恐怖の館',
#  '悪夢ちゃん The夢ovie',
#  '悪魔の命令',
#  '悪魔の寄生虫パラサイト',
#  '星の国から来た仲間',
#  '星の王子さま',
#  '時をかける少女',
#  '時計じかけのオレンジ',
#  '月に囚われた男',
#  '月世界征服',
#  '月影の下で',
#  '未来の想い出 Last Christmas',
#  '未来世紀ブラジル',
#  '未来忍者慶雲機忍外伝',
#  '未知との遭遇',
#  '未知との遭遇 特別編',
#  '未知との遭遇ファイナルカット版',
#  '来るべき世界',
#  '東海道お化け道中',
#  '極地からの怪物大カマキリの脅威',
#  '死の光線',
#  '死の谷間',
#  '死びとの恋わずらい',
#  '海底１万リーグからの妖獣',
#  '渚にて',
#  '猿の惑星',
#  '猿の惑星：創世記ジェネシス',
#  '猿の惑星：聖戦記グレートウォー',
#  '獣人繁殖',
#  '画面の向こうの君は',
#  '監禁惑星アメーバ',
#  '破壊的防御システムエンクリプト',
#  '竹取物語',
#  '第9地区',
#  '紅い眼鏡',
#  '終末へのカウントダウン',
#  '続星の国から来た仲間',
#  '肉喰怪獣キラーツリー',
#  '華氏451',
#  '蛇王子',
#  '謎多きポールWRの最後の旅',
#  '超能力者未知への旅人',
#  '近未来戦士テキサス2020年',
#  '遊星からの物体X',
#  '遊星からの物体X ファーストコンタクト',
#  '遊星からの物体Xファーストコンタクト',
#  '過去へ旅した女',
#  '量子の夏',
#  '金星ロケット発進す',
#  '闇に囁くもの',
#  '首都消失',
#  '魔界探偵ゴーゴリIII蘇りし者たちと最後の戦い',
#  '魔界探偵ゴーゴリII魔女の呪いと妖怪ヴィーの召喚',
#  '黙示録2009 急襲強酸雨',
#  'ＵＦＯ－オヘアの未確認飛行物体－']

# %%
len(folders)
# Out:
# 432

# %%
csv_folders=[]
for folder in folders:
    csv_folders.append(path+'/'+folder)

# %%
csv_folders
# Out:
# ['./review_csv/SF/12モンキーズ',
#  './review_csv/SF/2001年宇宙の旅',
#  './review_csv/SF/2001年宇宙の旅 新世紀特別版',
#  './review_csv/SF/200X年翔',
#  './review_csv/SF/2010年',
#  './review_csv/SF/2012',
#  './review_csv/SF/2020世界終焉の日',
#  './review_csv/SF/20世紀少年＜最終章＞ぼくらの旗',
#  './review_csv/SF/20世紀少年＜第1章＞終わりの始まり',
#  './review_csv/SF/20世紀少年＜第2章＞ 最後の希望',
#  './review_csv/SF/41',
#  './review_csv/SF/A1012K',
#  './review_csv/SF/AI',
#  './review_csv/SF/AIライジング',
#  './review_csv/SF/ANIARAアニアーラ',
#  './review_csv/SF/Archive原題',
#  './review_csv/SF/Ares英題',
#  './review_csv/SF/Astro原題',
#  './review_csv/SF/Auggie原題',
#  './review_csv/SF/AXLアクセル',
#  './review_csv/SF/Bacurau原題',
#  './review_csv/SF/Beyond the Sky原題',
#  './review_csv/SF/BillTedFacetheMusic原題',
#  './review_csv/SF/BLAMEブラム',
#  './review_csv/SF/Clara原題',
#  './review_csv/SF/Code8原題',
#  './review_csv/SF/ColdGround原題',
#  './review_csv/SF/COSMICRESCUETheMoonlightGenerations',
#  './review_csv/SF/CrazyAlien英題',
#  './review_csv/SF/CreatorsThePast原題',
#  './review_csv/SF/CreepyCrawlers英題',
#  './review_csv/SF/CrittersAttack原題',
#  './review_csv/SF/Dune 原題',
#  './review_csv/SF/ET',
#  './review_csv/SF/ET20周年アニバーサリー特別版',
#  './review_csv/SF/Fast Color原題',
#  './review_csv/SF/FREAKSフリークス能力者たち',
#  './review_csv/SF/GODZILLA ゴジラ',
#  './review_csv/SF/GODZILLA 怪獣惑星',
#  './review_csv/SF/I predatori di Atlantide／Atlantis Interceptors原題',
#  './review_csv/SF/Imitation Girl原題',
#  './review_csv/SF/Incontrol原題',
#  './review_csv/SF/iPSイントリュージョンオブプレデターステムセル',
#  './review_csv/SF/JurassicWorldDominion原題',
#  './review_csv/SF/LUCY／ルーシー',
#  './review_csv/SF/MEATBALLMACHINEミートボールマシン',
#  './review_csv/SF/MonsterHunt2英題',
#  './review_csv/SF/ParadiseHills原題',
#  './review_csv/SF/PLANETOFTHEAPES猿の惑星',
#  './review_csv/SF/PORTALSポータルズ',
#  './review_csv/SF/PREDATORPLANETプレデタープラネット',
#  './review_csv/SF/PRIVATEDREAMS',
#  './review_csv/SF/Pro9治験',
#  './review_csv/SF/PROSPECTプロスペクト',
#  './review_csv/SF/Psycho Goreman原題',
#  './review_csv/SF/Seat25原題',
#  './review_csv/SF/SFヘルスラッシャー',
#  './review_csv/SF/SFホイップクリーム',
#  './review_csv/SF/SinFin原題',
#  './review_csv/SF/Starfish原題',
#  './review_csv/SF/SUPER8／スーパーエイト',
#  './review_csv/SF/TakingTigerMountain原題',
#  './review_csv/SF/TAU／タウ',
#  './review_csv/SF/The Beast of Yucca Flats原題',
#  './review_csv/SF/TheCaseoftheMorituriDivisions英題',
#  './review_csv/SF/TheComingDays英題',
#  './review_csv/SF/TheDoll原題',
#  './review_csv/SF/TheInvisibleMansRevenge原題',
#  './review_csv/SF/TheInvisibleWoman原題',
#  './review_csv/SF/TheMonsterofPiedrasBlancas原題',
#  './review_csv/SF/TheNewMutants原題',
#  './review_csv/SF/ThePlatform英題',
#  './review_csv/SF/TheWave原題',
#  './review_csv/SF/TIME／タイム',
#  './review_csv/SF/TreasureoftheBitchIslands英題',
#  './review_csv/SF/UFOAbduction原題',
#  './review_csv/SF/UFO少年アブドラジャン',
#  './review_csv/SF/UnderElectricClouds英題',
#  './review_csv/SF/Vivarium原題',
#  './review_csv/SF/XMENファーストジェネレーション',
#  './review_csv/SF/Zero原題',
#  './review_csv/SF/だいじょうぶマイフレンド',
#  './review_csv/SF/てなもんや商社',
#  './review_csv/SF/アイアムレジェンド',
#  './review_csv/SF/アイススパイダー',
#  './review_csv/SF/アイランド',
#  './review_csv/SF/アイロボット',
#  './review_csv/SF/アキュムレーター1',
#  './review_csv/SF/アジアの逆襲',
#  './review_csv/SF/アジャストメント',
#  './review_csv/SF/アップグレード',
#  './review_csv/SF/アナイアレイション全滅領域',
#  './review_csv/SF/アフターアース',
#  './review_csv/SF/アベンジャーズ',
#  './review_csv/SF/アリーナ',
#  './review_csv/SF/アルファヴィル',
#  './review_csv/SF/アルマゲドン',
#  './review_csv/SF/アローン',
#  './review_csv/SF/アンドリューNDR114',
#  './review_csv/SF/アンドロメダストレイン',
#  './review_csv/SF/イカリエXB1',
#  './review_csv/SF/インセプション',
#  './review_csv/SF/インターステラー',
#  './review_csv/SF/インターセプター',
#  './review_csv/SF/インデペンデンスデイ',
#  './review_csv/SF/インデペンデンスデイ2019',
#  './review_csv/SF/インビジブル',
#  './review_csv/SF/インフィニティ無限ループ',
#  './review_csv/SF/イヴァーンヴァシーリエヴィチ転職する',
#  './review_csv/SF/ウォーターワールド',
#  './review_csv/SF/エイプマンの復讐',
#  './review_csv/SF/エイリアン',
#  './review_csv/SF/エイリアン2',
#  './review_csv/SF/エイリアン3',
#  './review_csv/SF/エイリアンVS プレデター',
#  './review_csv/SF/エイリアンアタック',
#  './review_csv/SF/エイリアントルネード',
#  './review_csv/SF/エイリアンノイド',
#  './review_csv/SF/エイリアンバトルロワイヤル',
#  './review_csv/SF/エイリアンフロムメテオ侵略',
#  './review_csv/SF/エイリアン／ディレクターズカット',
#  './review_csv/SF/エクスチェンジ脳間電送',
#  './review_csv/SF/エクスティンクション地球奪還',
#  './review_csv/SF/エリエリレマサバクタニ',
#  './review_csv/SF/エリジウム',
#  './review_csv/SF/エンドオブアース',
#  './review_csv/SF/エヴォリューション',
#  './review_csv/SF/オキュペーション侵略',
#  './review_csv/SF/オデッセイ',
#  './review_csv/SF/オブリビオン',
#  './review_csv/SF/オールユーニードイズキル',
#  './review_csv/SF/ガイバー／ダークヒーロー',
#  './review_csv/SF/ガジュラ',
#  './review_csv/SF/ガタカ',
#  './review_csv/SF/ガーディアンズオブギャラクシー：リミックス',
#  './review_csv/SF/キルボット',
#  './review_csv/SF/ギャラクシークエスト',
#  './review_csv/SF/クマエロヒーム',
#  './review_csv/SF/クリムゾンプラネット',
#  './review_csv/SF/クリーチャーオブダークネス',
#  './review_csv/SF/クロニクル',
#  './review_csv/SF/クローバーフィールドパラドックス',
#  './review_csv/SF/グリーンランタン',
#  './review_csv/SF/グレンとグレンダ',
#  './review_csv/SF/コクーン',
#  './review_csv/SF/コクーン2 遥かなる地球',
#  './review_csv/SF/コクーン2遥かなる地球',
#  './review_csv/SF/コロニー５',
#  './review_csv/SF/コンタクト',
#  './review_csv/SF/コードギアス亡国のアキト／第2章引き裂かれし翼竜',
#  './review_csv/SF/ゴーストインザシェル',
#  './review_csv/SF/サイキッカー 超人覚醒',
#  './review_csv/SF/サイボーグハンター ニューヨーク2019年',
#  './review_csv/SF/サイン',
#  './review_csv/SF/サインオブゴッド',
#  './review_csv/SF/サークルズ',
#  './review_csv/SF/ザコア',
#  './review_csv/SF/ザコンタクト',
#  './review_csv/SF/ザトランスフォーム',
#  './review_csv/SF/ザフライ',
#  './review_csv/SF/ザプロジェクト瞬間移動',
#  './review_csv/SF/ザホスト美しき侵略者',
#  './review_csv/SF/ザミスト',
#  './review_csv/SF/シャットダウン',
#  './review_csv/SF/ショートサーキット',
#  './review_csv/SF/ジェシカ',
#  './review_csv/SF/ジャンパー',
#  './review_csv/SF/ジュテームジュテーム',
#  './review_csv/SF/ジュピター',
#  './review_csv/SF/ジュブナイル',
#  './review_csv/SF/ジュラシックエクスペディション',
#  './review_csv/SF/ジュラシックサバイブ',
#  './review_csv/SF/ジュラシックワールド炎の王国',
#  './review_csv/SF/ジョナサンふたつの顔の男',
#  './review_csv/SF/スターウォーズ エピソード1／ファントムメナス',
#  './review_csv/SF/スターウォーズ エピソード2／クローンの攻撃',
#  './review_csv/SF/スターウォーズ エピソード3／シスの復讐',
#  './review_csv/SF/スターウォーズ エピソード4／新たなる希望',
#  './review_csv/SF/スターウォーズ エピソード5／帝国の逆襲',
#  './review_csv/SF/スターウォーズエピソード1／ファントムメナス',
#  './review_csv/SF/スターウォーズエピソード3／シスの復讐',
#  './review_csv/SF/スターウォーズエピソード4／新たなる希望',
#  './review_csv/SF/スターウォーズエピソード5／帝国の逆襲',
#  './review_csv/SF/スターウォーズエピソード6／ジェダイの帰還',
#  './review_csv/SF/スターウォーズ／ジェダイの帰還 特別篇',
#  './review_csv/SF/スターウォーズ／フォースの覚醒',
#  './review_csv/SF/スターウォーズ／帝国の逆襲特別篇',
#  './review_csv/SF/スターウォーズ／最後のジェダイ',
#  './review_csv/SF/スターシップトゥルーパーズ',
#  './review_csv/SF/スタートレック',
#  './review_csv/SF/スタートレックイントゥダークネス',
#  './review_csv/SF/ストーカー',
#  './review_csv/SF/スノーピアサー',
#  './review_csv/SF/スパイダーズ',
#  './review_csv/SF/スピーシーズXX寄生獣の誘惑',
#  './review_csv/SF/スペースエクスペンダブルズ',
#  './review_csv/SF/スペースポリス',
#  './review_csv/SF/スペースヴァンパイアQ',
#  './review_csv/SF/スローンズ 王都奪還',
#  './review_csv/SF/スーパーカミング完全版',
#  './review_csv/SF/スーパーマンリターンズ',
#  './review_csv/SF/セリーナ最強の暗殺者',
#  './review_csv/SF/ゼイカム到来',
#  './review_csv/SF/ゼログラビティ',
#  './review_csv/SF/ソリス',
#  './review_csv/SF/ソードレジェンド失われたドラゴンの剣',
#  './review_csv/SF/タイタン',
#  './review_csv/SF/タイタンAE',
#  './review_csv/SF/タイムトラベラー',
#  './review_csv/SF/ターミネーター',
#  './review_csv/SF/ターミネーター ニューフェイト',
#  './review_csv/SF/ターミネーター2',
#  './review_csv/SF/ターミネーター3',
#  './review_csv/SF/ターミネーター4',
#  './review_csv/SF/ターミネーターウォー',
#  './review_csv/SF/ターミネーター：新起動／ジェニシス',
#  './review_csv/SF/ダイバージェント',
#  './review_csv/SF/チキチキバンバン',
#  './review_csv/SF/チャッピー',
#  './review_csv/SF/ディストピア2049',
#  './review_csv/SF/デコーダー',
#  './review_csv/SF/デジャヴ',
#  './review_csv/SF/デスゲーム2025',
#  './review_csv/SF/デッドシティ2055',
#  './review_csv/SF/デメキング DEMEKING',
#  './review_csv/SF/デメキングDEMEKING',
#  './review_csv/SF/トゥルーマンショー',
#  './review_csv/SF/トランスフォーマー',
#  './review_csv/SF/トランスフォーマー最後の騎士王',
#  './review_csv/SF/トランスフォーマー／ダークサイドムーン',
#  './review_csv/SF/トランスフォーマー／リベンジ',
#  './review_csv/SF/トランスフォーマー／ロストエイジ',
#  './review_csv/SF/トランスモーファー人類最終戦争',
#  './review_csv/SF/トランセンデンス',
#  './review_csv/SF/トロン：レガシー',
#  './review_csv/SF/トワイライトゾーン／超次元の体験',
#  './review_csv/SF/トータルリコール',
#  './review_csv/SF/ドウエル教授の首',
#  './review_csv/SF/ドッペルゲンガー複製された者',
#  './review_csv/SF/ニューヨーク2014',
#  './review_csv/SF/ニルヴァーナ',
#  './review_csv/SF/ネイビーシールズ vs エイリアン',
#  './review_csv/SF/ネバーエンディングストーリー3',
#  './review_csv/SF/ネメシス',
#  './review_csv/SF/ノイズ',
#  './review_csv/SF/ノウイング',
#  './review_csv/SF/ハイライフ',
#  './review_csv/SF/ハイルミュタンテ／電撃XX作戦',
#  './review_csv/SF/ハルマゲドン',
#  './review_csv/SF/ハンガーゲーム',
#  './review_csv/SF/ハンガーゲーム FINAL：レボリューション',
#  './review_csv/SF/ハンガーゲーム2',
#  './review_csv/SF/ハンガーゲームFINAL：レジスタンス',
#  './review_csv/SF/ハンガーフォード',
#  './review_csv/SF/バタフライエフェクト',
#  './review_csv/SF/バックトゥザフューチャー',
#  './review_csv/SF/バックトゥザフューチャーPART2',
#  './review_csv/SF/バックトゥザフューチャーPART3',
#  './review_csv/SF/バトルシップ',
#  './review_csv/SF/バトルスカイ',
#  './review_csv/SF/バトルドローン',
#  './review_csv/SF/バトルハザード',
#  './review_csv/SF/バベル失われた地図と魔法の水晶',
#  './review_csv/SF/パシフィックリム',
#  './review_csv/SF/パシフィックリムアップライジング',
#  './review_csv/SF/パラサイト地球外生命体',
#  './review_csv/SF/ヒズマスターズヴォイス',
#  './review_csv/SF/ピクセル',
#  './review_csv/SF/ピノキオニューアドベンチャー',
#  './review_csv/SF/ファイナルハザード',
#  './review_csv/SF/ファイナルフェーズ 破壊',
#  './review_csv/SF/ファーストコンタクト',
#  './review_csv/SF/フィフスエレメント',
#  './review_csv/SF/フィフスパッセンジャー',
#  './review_csv/SF/フランケンウィニー',
#  './review_csv/SF/フレッシュゴードン／SPACEWARS',
#  './review_csv/SF/ブライトバーン恐怖の拡散者',
#  './review_csv/SF/ブラックパンサー',
#  './review_csv/SF/ブラックミラーバンダースナッチ',
#  './review_csv/SF/ブレードランナー',
#  './review_csv/SF/ブレードランナー2049',
#  './review_csv/SF/ブレードランナーファイナルカット',
#  './review_csv/SF/ブロンクスウォリアーズ／1990年の戦士',
#  './review_csv/SF/プラネットオブエイリアン',
#  './review_csv/SF/プラン9フロムアウタースペース',
#  './review_csv/SF/プレデターズ',
#  './review_csv/SF/プロトタイプマナ制御不能',
#  './review_csv/SF/プロメテウス',
#  './review_csv/SF/ホテルアルテミス～犯罪者専門闇病院～',
#  './review_csv/SF/ホワイトスペース',
#  './review_csv/SF/ホンモノの気持ち',
#  './review_csv/SF/ボルケーノアルマゲドン',
#  './review_csv/SF/ポストアポカリプス',
#  './review_csv/SF/ポーラーサークル未知なる漫画家オムニバス',
#  './review_csv/SF/マシーンオブザデッド',
#  './review_csv/SF/マダムハイド',
#  './review_csv/SF/マックィーンの絶対の危機ピンチ',
#  './review_csv/SF/マッドファイター',
#  './review_csv/SF/マッドマックス2',
#  './review_csv/SF/マッドマックス怒りのデスロード',
#  './review_csv/SF/マッドレイジ Z',
#  './review_csv/SF/マトリックス',
#  './review_csv/SF/マトリックス レボリューションズ',
#  './review_csv/SF/マトリックスリローデッド',
#  './review_csv/SF/マペットのクリスマスキャロル',
#  './review_csv/SF/マンオブスティール',
#  './review_csv/SF/マーズアタック',
#  './review_csv/SF/ミクロキッズ3',
#  './review_csv/SF/ミスト',
#  './review_csv/SF/ミッション8ミニッツ',
#  './review_csv/SF/ミムジー 〜未来からのメッセージ〜',
#  './review_csv/SF/ミラクルニール',
#  './review_csv/SF/メッセージ',
#  './review_csv/SF/メトロポリス',
#  './review_csv/SF/メトロポリス 完全復元版',
#  './review_csv/SF/メンインブラック',
#  './review_csv/SF/メンインブラック2',
#  './review_csv/SF/メンインブラック3',
#  './review_csv/SF/メンインブラック：インターナショナル',
#  './review_csv/SF/モンスターアイランド',
#  './review_csv/SF/ライフ',
#  './review_csv/SF/ラジュテ',
#  './review_csv/SF/ラストフランケンシュタイン',
#  './review_csv/SF/ラストマン地球最後の男',
#  './review_csv/SF/ラストラブレター',
#  './review_csv/SF/ラビッド',
#  './review_csv/SF/ランドオブザロスト',
#  './review_csv/SF/リアリティ',
#  './review_csv/SF/リディック：ギャラクシーバトル',
#  './review_csv/SF/リバーワールド',
#  './review_csv/SF/リミットレス',
#  './review_csv/SF/ルーシーインザスカイ',
#  './review_csv/SF/レイトフォーディナー',
#  './review_csv/SF/レッドサイクロン',
#  './review_csv/SF/レディプレイヤー1',
#  './review_csv/SF/レプリカズ',
#  './review_csv/SF/レプリケイト－襲撃－',
#  './review_csv/SF/レベル16服従の少女たち',
#  './review_csv/SF/ロストチルドレン',
#  './review_csv/SF/ロックアップスペースロック',
#  './review_csv/SF/ロックダウン非常事態',
#  './review_csv/SF/ロックネス',
#  './review_csv/SF/ロボコップ',
#  './review_csv/SF/ロボジョックス',
#  './review_csv/SF/ロボットコップレボリューション',
#  './review_csv/SF/ワールズエンド酔っぱらいが世界を救う',
#  './review_csv/SF/ワールドエンド',
#  './review_csv/SF/ヴァストオブナイト',
#  './review_csv/SF/ヴァレリアン千の惑星の救世主',
#  './review_csv/SF/ヴィクターフランケンシュタイン',
#  './review_csv/SF/三人の夫',
#  './review_csv/SF/世界侵略 ワシントン決戦',
#  './review_csv/SF/世界侵略ロサンゼルス決戦',
#  './review_csv/SF/世紀の怪物／タランチュラの襲撃',
#  './review_csv/SF/丹波哲郎の大霊界2 死んだらおどろいた',
#  './review_csv/SF/丹波哲郎の大霊界2死んだらおどろいた',
#  './review_csv/SF/丹波哲郎の大霊界死んだらどうなる',
#  './review_csv/SF/人類滅亡計画書',
#  './review_csv/SF/今日昨日明日',
#  './review_csv/SF/吸血鬼ゴケミドロ',
#  './review_csv/SF/囚われた国家',
#  './review_csv/SF/地球が静止する日',
#  './review_csv/SF/地球を守れ',
#  './review_csv/SF/大災獣ニゲロン',
#  './review_csv/SF/天才少年ジミーニュートロン',
#  './review_csv/SF/孤独なふりした世界で',
#  './review_csv/SF/宇宙人ポール',
#  './review_csv/SF/宇宙少女ゼノン',
#  './review_csv/SF/宇宙戦争',
#  './review_csv/SF/宇宙水爆戦',
#  './review_csv/SF/宮田バスターズ株',
#  './review_csv/SF/寄生体X',
#  './review_csv/SF/寄生獣',
#  './review_csv/SF/巨大目玉の怪獣トロレンバーグの恐怖',
#  './review_csv/SF/幻の湖',
#  './review_csv/SF/怪物の花嫁',
#  './review_csv/SF/恋はデジャブ',
#  './review_csv/SF/恐怖の館',
#  './review_csv/SF/悪夢ちゃん The夢ovie',
#  './review_csv/SF/悪魔の命令',
#  './review_csv/SF/悪魔の寄生虫パラサイト',
#  './review_csv/SF/星の国から来た仲間',
#  './review_csv/SF/星の王子さま',
#  './review_csv/SF/時をかける少女',
#  './review_csv/SF/時計じかけのオレンジ',
#  './review_csv/SF/月に囚われた男',
#  './review_csv/SF/月世界征服',
#  './review_csv/SF/月影の下で',
#  './review_csv/SF/未来の想い出 Last Christmas',
#  './review_csv/SF/未来世紀ブラジル',
#  './review_csv/SF/未来忍者慶雲機忍外伝',
#  './review_csv/SF/未知との遭遇',
#  './review_csv/SF/未知との遭遇 特別編',
#  './review_csv/SF/未知との遭遇ファイナルカット版',
#  './review_csv/SF/来るべき世界',
#  './review_csv/SF/東海道お化け道中',
#  './review_csv/SF/極地からの怪物大カマキリの脅威',
#  './review_csv/SF/死の光線',
#  './review_csv/SF/死の谷間',
#  './review_csv/SF/死びとの恋わずらい',
#  './review_csv/SF/海底１万リーグからの妖獣',
#  './review_csv/SF/渚にて',
#  './review_csv/SF/猿の惑星',
#  './review_csv/SF/猿の惑星：創世記ジェネシス',
#  './review_csv/SF/猿の惑星：聖戦記グレートウォー',
#  './review_csv/SF/獣人繁殖',
#  './review_csv/SF/画面の向こうの君は',
#  './review_csv/SF/監禁惑星アメーバ',
#  './review_csv/SF/破壊的防御システムエンクリプト',
#  './review_csv/SF/竹取物語',
#  './review_csv/SF/第9地区',
#  './review_csv/SF/紅い眼鏡',
#  './review_csv/SF/終末へのカウントダウン',
#  './review_csv/SF/続星の国から来た仲間',
#  './review_csv/SF/肉喰怪獣キラーツリー',
#  './review_csv/SF/華氏451',
#  './review_csv/SF/蛇王子',
#  './review_csv/SF/謎多きポールWRの最後の旅',
#  './review_csv/SF/超能力者未知への旅人',
#  './review_csv/SF/近未来戦士テキサス2020年',
#  './review_csv/SF/遊星からの物体X',
#  './review_csv/SF/遊星からの物体X ファーストコンタクト',
#  './review_csv/SF/遊星からの物体Xファーストコンタクト',
#  './review_csv/SF/過去へ旅した女',
#  './review_csv/SF/量子の夏',
#  './review_csv/SF/金星ロケット発進す',
#  './review_csv/SF/闇に囁くもの',
#  './review_csv/SF/首都消失',
#  './review_csv/SF/魔界探偵ゴーゴリIII蘇りし者たちと最後の戦い',
#  './review_csv/SF/魔界探偵ゴーゴリII魔女の呪いと妖怪ヴィーの召喚',
#  './review_csv/SF/黙示録2009 急襲強酸雨',
#  './review_csv/SF/ＵＦＯ－オヘアの未確認飛行物体－']

# %%
csv_files = []
for folder in csv_folders:
    files = os.listdir(folder)
    for file in files:
        csv_files.append(folder+'/'+file)
